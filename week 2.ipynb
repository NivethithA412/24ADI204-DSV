# %% [markdown]
# # Week 2 – Know Your Data
#
# ## Objective
#
# The objective of this week is to understand the dataset before performing any data cleaning.
#
# The following activities are performed:
# - Loading the dataset
# - Inspecting the dataset structure
# - Checking the number of rows and columns
# - Identifying column names
# - Checking data types
# - Identifying numerical and categorical attributes
# - Generating descriptive statistics
# - Checking unique values
# - Identifying missing values
# - Checking duplicate records
# - Preparing the First Impression Report

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-e5a0c701-4f16-4e04-bbc0-6fd8ca0721f9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e5a0c701-4f16-4e04-bbc0-6fd8ca0721f9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## 1. Loading the Dataset
#
# The dataset is loaded using Pandas.
#
# Pandas provides useful functions for reading, inspecting, cleaning, and analyzing tabular data.

# %%
df = pd.read_csv("data_jobs.csv")

# %% [markdown]
# ## 2. Inspecting the Dataset Structure
#
# The structure of the dataset is inspected to understand its size, columns, and records.
#
# The `shape`, `columns`, `head()`, and `tail()` functions are used for this purpose.

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %%
df.shape
# Out:
# (785741, 17)

# %%
df.columns
# Out:
# Index(['job_title_short', 'job_title', 'job_location', 'job_via',
#        'job_schedule_type', 'job_work_from_home', 'search_location',
#        'job_posted_date', 'job_no_degree_mention', 'job_health_insurance',
#        'job_country', 'salary_rate', 'salary_year_avg', 'salary_hour_avg',
#        'company_name', 'job_skills', 'job_type_skills'],
#       dtype='object')

# %%
df.tail()
# Out:
#           job_title_short                                          job_title  \
# 785736  Software Engineer                                    DevOps Engineer
# 785737       Data Analyst                                   CRM Data Analyst
# 785738   Business Analyst                     Commercial Analyst - Start Now
# 785739      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740  Software Engineer                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home search_location  \
# ...

# %% [markdown]
# ## 3. Inspecting Dataset Information
#
# The `info()` function is used to inspect the column names, number of non-null values, data types, and memory usage.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %% [markdown]
# ## 4. Checking Data Types
#
# The data types of all attributes are examined to understand how the values are stored.
#
# At this stage, the data types are only inspected. Any required corrections will be handled during Week 3 – Data Cleaning.

# %%
df.dtypes
# Out:
# job_title_short           object
# job_title                 object
# job_location              object
# job_via                   object
# job_schedule_type         object
# job_work_from_home          bool
# search_location           object
# job_posted_date           object
# job_no_degree_mention       bool
# job_health_insurance        bool
# job_country               object
# salary_rate               object
# salary_year_avg          float64
# salary_hour_avg          float64
# company_name              object
# job_skills                object
# job_type_skills           object
# dtype: object

# %% [markdown]
# ## 5. Identifying Numerical Attributes
#
# Numerical attributes contain values that can be used for mathematical calculations.
#
# These attributes are identified using Pandas.

# %%
df.select_dtypes(include='number').columns
# Out:
# Index(['salary_year_avg', 'salary_hour_avg'], dtype='object')

# %% [markdown]
# ## 6. Identifying Categorical Attributes
#
# Categorical attributes contain text or category-based information such as job titles, locations, countries, companies, and job types.

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['job_title_short', 'job_title', 'job_location', 'job_via',
#        'job_schedule_type', 'search_location', 'job_country', 'salary_rate',
#        'company_name', 'job_skills', 'job_type_skills'],
#       dtype='object')

# %% [markdown]
# ## 7. Descriptive Statistics
#
# Descriptive statistics are generated for the numerical attributes.
#
# The statistics include count, mean, standard deviation, minimum, quartiles, and maximum values.

# %%
df.describe()
# Out:
#                      job_posted_date  salary_year_avg  salary_hour_avg
# count                         785741    785741.000000     10662.000000
# mean   2023-06-25 16:02:11.860248576    115232.039423        47.016598
# min              2023-01-01 00:00:04     15000.000000         8.000000
# 25%              2023-03-20 10:05:48    115000.000000        27.500000
# 50%              2023-06-29 06:11:38    115000.000000        45.980000
# 75%              2023-09-27 01:01:16    115000.000000        61.159996
# max              2023-12-31 23:59:58    960000.000000       391.000000
# std                              NaN      8199.225717        21.890738

# %% [markdown]
# ## 8. Descriptive Statistics for Categorical Attributes
#
# Categorical attributes are examined using descriptive statistics such as count, unique values, most frequent value, and its frequency.

# %%
df.describe(include='object')
# Out:
#        job_title_short      job_title job_location       job_via  \
# count           785741         785741       785741        785741
# unique              10         234674        17218          7904
# top       Data Analyst  Data Engineer     Anywhere  via LinkedIn
# freq            196075          53908        69552        186679
#
#        job_schedule_type search_location    job_country salary_rate  \
# count             785741          785741         785741       33067
# unique                48             173            161           5
# top            Full-time           India  United States        year
# freq              701727           51088         206292       22004
#
#        company_name job_skills               job_type_skills
# count        785741     668704                        668704
# unique       139983     177562                        177562
# top         Emprego  ['excel']  {'analyst_tools': ['excel']}
# ...

# %% [markdown]
# ## 9. Checking Unique Values
#
# The number of unique values in each column is examined to understand the variety of information present in the dataset.

# %%
df.nunique()
# Out:
# job_title_short              10
# job_title                234674
# job_location              17218
# job_via                    7904
# job_schedule_type            48
# job_work_from_home            2
# search_location             173
# job_posted_date          607192
# job_no_degree_mention         2
# job_health_insurance          2
# job_country                 161
# salary_rate                   5
# salary_year_avg            2702
# salary_hour_avg            1184
# company_name             139983
# job_skills               177562
# job_type_skills          177562
# dtype: int64

# %% [markdown]
# ## 10. Checking Missing Values
#
# Missing values are identified using `isnull()`.
#
# At this stage, missing values are only identified and reported. They will be handled during Week 3 – Data Cleaning.## 10. Checking Missing Values

# %%
df.isnull().sum()
# Out:
# job_title_short               0
# job_title                     0
# job_location                  0
# job_via                       0
# job_schedule_type             0
# job_work_from_home            0
# search_location               0
# job_posted_date               0
# job_no_degree_mention         0
# job_health_insurance          0
# job_country                   0
# salary_rate              752674
# salary_year_avg               0
# salary_hour_avg          775079
# company_name                  0
# job_skills               117037
# job_type_skills          117037
# dtype: int64

# %% [markdown]
# ## 11. Checking Duplicate Records
#
# Duplicate records are identified using the `duplicated()` function.
#
# At this stage, duplicate records are only identified. They will be examined and handled during Week 3 – Data Cleaning.

# %%
df.duplicated().sum()
# Out:
# np.int64(101)

# %% [markdown]
# # First Impression Report
#
# ## Dataset Overview
#
# The selected dataset is a job-posting dataset obtained from the Hugging Face dataset repository `lukebarousse/data_jobs`.
#
# The dataset contains information related to job postings, including job titles, locations, job types, countries, salary information, companies, and required skills.
#
# ## Dataset Structure
#
# The dataset contains multiple numerical, categorical, Boolean, and text-based attributes.
#
# The structure and data types of all attributes were inspected using Pandas.
#
# ## Numerical Attributes
#
# The numerical attributes were identified using `select_dtypes()` and examined using descriptive statistics.
#
# ## Categorical Attributes
#
# The categorical attributes include job-related information such as job title, job location, job source, schedule type, country, salary rate, company name, and skill information.
#
# ## Missing Values
#
# Missing values were identified using `isnull().sum()`.
#
# These missing values will not be modified during Week 2. They will be analyzed and handled appropriately during Week 3.
#
# ## Duplicate Records
#
# Duplicate records were identified using `duplicated().sum()`.
#
# They will be further examined and handled during Week 3.
#
# ## Initial Observations
#
# - The dataset contains job-posting information.
# - The dataset contains both numerical and categorical attributes.
# - Salary-related attributes contain numerical values and missing values.
# - Several job-related attributes contain categorical/text information.
# - Missing values are present in some attributes.
# - Duplicate records are checked but not removed during Week 2.
# - Data types are inspected but not modified.
# - No data cleaning or transformation is performed during Week 2.
#
# ## Conclusion
#
# The initial inspection provides an understanding of the dataset structure and data quality issues.
#
# The identified missing values, duplicate records, and possible data-type issues will be addressed during Week 3 – The Cleaning Sprint.
